# %%
# This is an example snippet!
# To create your own, add a new snippet block to the
# snippets.json file in your jupyter nbextensions directory:
# /nbextensions/snippets/snippets.json
import this

# %% [markdown]
# # <center><font face="arial" size="5" color=#0101DF>NUMERIQUE ET SCIENCES INFORMATIQUES 1ère NSI</font></center>

# %% [markdown]
# ## <font color=#013ADF>Séquence N° 5 : Réseaux WEB - Les langages HTML, CSS et JS</font>

# %% [markdown]
# <div class="alert alert-danger" role="alert">
#
# **Objectifs** :
#
# - Rafraichir ses connaissances sur les langages HTML et CSS ;
# - Découvrir le langage Javascript pour réaliser une application ;
# - Identifier les différents composants graphiques permettant d'interagir avec une application Web ;
# - Identifier les événements que les fonctions associées aux différents composants graphiques sont capables de traiter ;
# - Analyser et modifier les méthodes exécutées lors d'un clic sur un bouton d'une page Web ;
# - Comparer des langages de programmation (python, javascript).

# %% [markdown]
# - Téléchargez le fichier "debutant_html_css_js.zip" et décompressez le.
#
# Pour créer une page Web, il faut un langage capable d'insérer du **contenu** (texte, image ...). Ce langage est le **HTML** pour Hyper Text Markup Language.
#
# Il faut rendre sa page attractive pour que le visiteur ait envie de s'y attarder (la concurrence est rude). Le **style** de la page est réalisée avec le langage **CSS** pour Cascading Style Sheet.
#
# - Pour s'en convaincre, placez vous dans le répertoire "debutant_html_css_js" et ouvrir le fichier "basic_page.html" dans un navigateur.
#
# Une page HTML s'affiche, mais le lien vers la feuille de style (CSS) a été volontairement rompu : vous n'avez que du langage HTML.
#
# On peut visualiser de plusieurs manières son contenu. Nous allons passer par le navigateur en appuyant simultanément sur les touches **Ctrl + Maj + I (ou F12)**
#
# - Inspectez le contenu de la page en passant la souris sur les différentes balises (inspecteur).
# - Ouvrir le fichier "basic_page.html" avec un éditeur de texte.
#
# Après la déclaration du type de fichier et du langage (ici fr pour français), vous pouvez observer 2 grandes parties :
#
# 1. L'entête (**head**) qui contient des méta données qui ne s'affichent pas (à l'exception du titre de la page) ;
#
# 2. Le corps (**body**) où l'on peut voir le contenu de la page.
#
# Le HTML est un langage à balises, une première ouvrante et une seconde fermante. Il en existe un nombre important que vous pouvez consulter à l'adresse suivante :
#
# https://www.w3schools.com/
#
# -  Activez la feuille de style liée au fichier "basic_page.html" en décommentant la ligne du fichier qui fait le lien avec la feuille de style "basic_style.css".
#
# Notez que cette feuille se trouve dans un sous-répertoire "styles".
#
# - Actualisez la page du navigateur, un style (modeste) doit y être appliqué (couleurs).
# - Ouvrir le fichier "basic_styles.css" avec un éditeur de texte.
#
# Vous pouvez constater que l'on a attribué aux balises HTML des attributs de couleurs, de taille, d'alignement ...
#
# La description de tous ces attributs est disponible à la même adresse que précédemment.

# %% [markdown]
# <div class="alert alert-success">
#
# > Conclusion : Pour créer une page Web agréable à parcourir, il faudra conjuguer les 2 langages précédents.
# </div>

# %% [markdown]
# Cependant, quelque soit la qualité de votre page, elle sera statique. C'est-à-dire que quelque soit l'internaute qui la consulte, chaque fois qu'on accède à votre page, elle est identique.
#
# Pour qu'une interaction entre la page et l'utilisateur soit possible, il nous faut un autre langage. Ce sera pour nous, le **JAVASCRIPT**.
#
# - Fermez l'éditeur de texte et le navigateur.
# - Retournez dans le répertoire "debutant_html_css_js" et ouvrir le fichier "demonstration.html" dans un navigateur.
#
# La page est déjà plus étoffée, grâce au HTML et au CSS.
#
# - Interagissez avec la page et observez le comportement de celle-ci. Soyez attentif !
#
# Un lien vers un script a été ajouté à l'entête du fichier HTML "demonstration.html". Notez que ce script se trouve dans un sous-répertoire "scripts".

# %% [markdown]
# <div class="alert alert-success">
# <img src="Images/warning.png" alt="logo warn" width=5% align=left>
#
# **Objectif** : Lors d'une prochaine séquence, vous aurez à réaliser un programme en javascript. Les manipulations proposées doivent vous permettre de découvrir le langage.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <img src="Images/CR.png" alt="logo CR" width=5% align=right>
#
# - Ouvrez avec un éditeur de texte, les fichiers "demonstration.html" et "script_demo.js" ;
# - Lancez dans un navigateur le fichier "demonstration.html" ;
#
# > **Explorez les différentes interactions entre vous et la page Web**, puis en analysant les 2 fichiers ouverts, répondez aux questions en faisant éventuellement des copier/coller.
#
# Les couleurs utilisées ont le mérite de bien marquer les différentes zones de la page.
#
# - La zone bleue est un formulaire pour un mini sondage ;
# - La zone jaune est quasiment autonome ;
# - La zone grise fait un bilan de vos activités sur les zones bleues et vertes ;
# - Les bandeaux rouges (haut et bas) interagissent avec les zones jaunes et vertes.
#
# *Remarque* : L'appui sur le bouton "Reset page" réinitialise la page à sa forme d'origine.
#
#
# **Questionnaire** :
#
# Les 2 fichiers "demonstration.html" et "script_demo.js" sont liés (à la manière d'un fichier CSS).
#
# 1. Dans lequel de ces 2 fichiers se trouve le lien ?
#
# ```
#     le lien se trouve dans le fichier html
#
# ```
#
# 2. Écrivez ici l'intégralité du lien :
#
# ```
#     <script src="scripts/script_demo.js"></script>
#
# ```
#
# 3. Donnez les identifiants (id) des différentes zones de couleurs de la page :
#
# ```
#     hg-hd-bg-bd-haut-bas
#
# ```
#
# **Pour les questions suivantes, on s'intéresse principalement à la zone jaune**.
#
# 4. Donnez le nom de la fonction JS qui permet le transfert du texte "Source" vers "Destination" :
#
# ```
#     transferer()
#
# ```
#
# 5. Quelle est la méthode de JS qui permet de récupérer le contenu d'un élément "input" de type "text" ?
#
# ```
#     .value
#
# ```
#
# 6. Quelle balise (tag) HTML et quel id sont attribués à la variable "messageActuel" ?
#
# ```
#     h1 id="message"
#
# ```
#
# 7. À quel endroit sur la page le message "Message transféré !" s'affiche ?
#
# ```
#     body "haut"
#
# ```
#
# 8. Quelles sont les méthodes JS qui permettent d'écrire  "Message transféré !" ?
#
# ```
#     let messageActuel = document.getElementById("message");
# 	messageActuel.innerHTML="Message transféré !";
#
# ```
#
# 9. Quelle option impose l'écriture "Source" et "Destination" dans les champs de type "text" dans le fichier HTML ?
#
# ```
#     placeholder="Source"
#
# ```
#
# 10. Quelle est la taille maximale du texte dans le champ "Source" ? Quelle option impose cela ?
#
# ```
#     maxlength="10"
#
# ```
#
# Pour finir avec cette partie, notez la simplicité et l'efficacité de "Clic sur moi" !
# Claqué au sol
#
#
# **Pour les questions suivantes, on s'intéresse principalement à la zone bleue : le sondage**.
#
# 11. Comme indiqué précédemment, le sondage est un formulaire. Quelle balise HTML encadre ce formulaire ?
#
# ```
#         <form>
#
# ```
# 😒
# 12. Quel est le nom de la fonction JS appelée lors de l'appui sur le bouton "Valider" ?
#
# ```
#    AfficheChoix()
#
# ```
#
# 13. Quelle est la méthode JS qui récupère l'information "Majeur(e)" ou "Mineur(e)" ?
#
# ```
#             let choix=document.getElementsByName('statut');
#
# ```
#
# 14. Dans la fonction précédente, quel est le nom de la variable utilisée ? De quelle nature est cette variable ?
#
# ```
#             valeur1 : None puis STR
#
# ```
#
# 15. Quelle est la méthode JS qui récupère l'information du mode de transport ?
#
# ```
#             .value
#
#
# ```
#
# 16. Dans la fonction précédente, quel est le nom de la variable utilisée ? De quelle nature est cette variable ?
#
# ```
#             valeur2
#
# ```
#
# 17. Quelle est la méthode JS qui permet d'écrire les messages dans la zone grise ?
#
# ```
#             innerHTML
#
# ```
#
# 18. Que se passe t-il s'il y a 2 moyens de locomotion cochés ?
#
# ```
#             .innerHTML "Vous n'avez pas l'air de trop savoir. Il y a 2 cases cochées"
#
# ```
#
# Javascript est capable de vous alerter avec des fenêtres popup (ce n'est plus vraiment à la mode : Qu est ce que tu veux), mais en tant que développeur, vous pouvez visualiser l'état des variables dans une console de développement et en mettant dans le programme, des commandes de type : console.log(variable à afficher).
#
# - Ouvrez les outils de développement (Ctrl + Maj + I), puis sélectionnez l'onglet console ;
# - Sélectionnez plusieurs options de locomotion dans le sondage, puis validez. Vous devriez voir apparaître le nombre de cases cochées.
#
# 19. Écrivez ci-dessous, la commande qui a permis cet affichage :
#
# ```
#             console.log(nombre);
#
# ```
#
# 20. Lorsque l'on appuie sur le bouton "test" (zone verte), un popup s'affiche. Écrivez ci-dessous, la commande qui a provoqué cet événement :
#
# ```
#             alert('Test réussi !')"
#
# ```
#
# **Comparons les langages python et javascript**
#
# 21. Dans la table ci-dessous, vous trouverez des éléments de langage en python. On vous demande de compléter l'équivalent (s'il existe) en javascript en parcourant le script "script_demo.js" :
#
# | Action                                                  | Python                | Javascript |
# | ------------------------------------------------------- | --------------------- | :--------- |
# | Déclarer une variable (int)                             | compteur=0            |let compteur=0|
# | Déclarer une variable (str)                             | texte="allumée"       |let texte="allumée"|
# | Incrémenter une variable "compteur"                     | compteur+=1           |compteur++|
# | Recherche d'un élément dans une liste (tableau) "choix" | choix[i]              |choix[i]|
# | Connaître le nombre d'élément d'une liste (tableau)     | len                   |.length|
# | Tester l'égalité dans une condition de test             | ==                    |==|
# | Faire une opération logique dans une condition de test  | or                    ||||
# | Déclarer une fonction                                   | def mafonction():     |function afficheChoix(){}|
# | Structure itérative POUR                                | for i in range (10) : |for(let i = 0; i < 10; i++){}|
# | Structure conditionnelle SI                             | if condition :        |if(condition){}|
# |                                                         | else:                 |else{}|
#
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# > Conclusion : Pour réaliser une page HTML, on utilise les langages HTML, CSS et JS. Pour développer ces fichiers, on a besoin d'un navigateur avec ses outils de débuggage et d'un éditeur de texte. On notera au pass
#     age que ces applications sont disponibles sur n'importe quel micro-ordinateur.
# </div>
