# %% [markdown]
# # <center><font face="arial" size="5" color=#0101DF>NUMERIQUE ET SCIENCES INFORMATIQUES Terminale NSI</font></center>

# %% [markdown]
# ## <font color=#013ADF>Séquence N° 3 : Structures linéaires : listes, piles et files</font>

# %% [markdown]
# <div class="alert alert-danger" role="alert">
#
# Les objectifs de cette séquence sont :
#
# - Distinguer des structures par le jeu des méthodes qui les caractérisent ;
# - Choisir une structure de données adaptée à la situation à modéliser ;
# - Distinguer la recherche d'une valeur dans une liste et dans un dictionnaire.
#
#
# </div>

# %% [markdown]
# ### 1- Implémentation  d'une liste (chainée)

# %% [markdown]
# On pourrait utiliser des types natifs à python tels que des listes (objet list) ou des couples (objet tuple) comme cela est réalisé dans le livre. On va choisir une autre solution en créant une classe privée "Noeud" (qui sera invisible à l'utilisateur) dans la classe "Liste".
# La liste ainsi implémentée sera une liste dite chaînée puisque le noeud (ou cellule) pointe vers le noeud suivant ou vers un noeud vide (⊥).
#
# On peut en faire cette représentation schématique :
# ![](Images/liste_chainee.png)
#
# Une liste est soit la valeur vide (None en python), soit un objet de la classe "Noeud" dont l'attribut "noeud suivant" contient une liste. C'est une définition récursive de la notion de liste.

# %% [markdown]
# <div class="alert alert-warning">
# <img src="Images/CR.png" alt="logo CR" width=5% align=right>
#
# Travail à faire
#
# Créer une classe "Noeud" contenant les trois méthodes suivantes :
# - Le constructeur qui initialise deux attributs d'instance **donnee** et **suivant** :
#     - L'attribut **donnee**, de type entier, sera initialisée à l'aide de l'argument **donnee**.
#     - L'attribut **suivant**, de type **Noeud**, sera initialisé avec l'argument de type **Noeud** qui aura pour valeur par défaut **None**;
# - La méthode d'instance **aff_noeud** qui affichera la chaîne de caractères représentant le noeud ;
# - La méthode spéciale `__repr__` qui renverra de manière récursive, la chaîne de caractères représentant le premier noeud ainsi que ses successeurs.
#
# *Exemple d'exécution* :
#
# n1 = Noeud(3)
#
# n2 = Noeud(2, n1)
#
# n3 = Noeud(1, n2)
#
# print(n3)
#
# [1  [2  [3  None]]]
#
# n3.aff_noeud()
#
# '[1  . ]'
#
# **On pourrait également faire :**
#
# liste=Noeud(4, Noeud(5, Noeud(6, Noeud(7,None))))
#
# print(liste)
#
# [4  [5  [6  [7  None]]]]
#
# <div>

# %%
class Noeud:
    """
    classe implémentant un noeud (ou maillon).
    Le premier argument passé à l'instanciation est la donnée
    Le second set le lien vers le noeud suivant.
    """
    def __init__(self, donnee=None, noeud_suivant=None):
        self.donnee = donnee
        self.suivant = noeud_suivant

    def affiche_noeud(self): # faire un test avec la méthode __str__ pour voir la différence.
        """
        Méthode qui permet d'afficher
        le noeud passé en paramètre
        """
        return f'[{self.donnee}  . ]'

    def __repr__(self):
        """
        Méthode qui permet d'afficher
        de manière récursive la liste chainée
        à partir du noeud passé en paramètre
        """
        return f'[{self.donnee}  {self.suivant}]'

# %%
n1 = Noeud(3)
n2 = Noeud(2, n1)
n3 = Noeud(1, n2)
n4 = Noeud()

print(n3)
n3.affiche_noeud() #print(n3.affiche_noeud()) supprime les guillements

liste=Noeud(4, Noeud(5, Noeud(6, Noeud(7,None))))
print(liste)

# %% [markdown]
# <div class="alert alert-success">
# <img src="Images/warning.png" alt="logo warn" width=5% align=left>
#
# Nous venons de créer une liste chaînée mais on peut lui faire quelques reproches :
# - Son utilisation n'est pas des plus simple ;
# - Si je change l'implémentation de la classe, tous les programmes l'utilisant seront impactés ;
# - l'utilisateur de la classe n'est en général pas intéressé par la manière dont l'implémentation est réalisée.
#
#  <div>

# %% [markdown]
# **On décide d'utiliser l'interface suivante pour les listes (chaînées) :**
#
# ```python
# class InterfaceListe:
#     def __init__(self, donnee=None, liste=None):
#         '''
#         Constructeur permettant de créer une nouvelle liste. Cette liste peut être :
#             - Une liste vide
#             - Une liste ayant pour tête le maillon contenant donnee et pour queue liste
#                 argument donnee : Donnée à ajouter en tête de liste
#                 argument liste : Liste représentant la queue de nouvelle liste
#         '''
#         pass
#
#     def est_vide(self) -> bool:
#         '''
#         Méthode permettant de tester si la liste est vide
#         renvoie True si la liste est vide, False sinon
#         '''
#         pass
#
#     def insere(self, donnee : int):
#         '''
#         Méthode permettant d'ajouter un maillon en tête de liste
#         argument donnee : donnée du maillon à ajouter
#         '''
#         pass
#
#     def supprime(self) -> int:
#         '''
#         Méthode permettant de supprimer le maillon en tête de liste
#         et renvoie la donnée du nouveau maillon de tête
#         '''
#         pass
#
#     def get_tete(self)-> int:
#         '''
#         Méthode permettant de renvoyer la donnée du maillon en tête
#         de liste
#         '''
#         pass
#
#     def get_queue(self)-> Liste:
#         '''
#         Méthode permettant de renvoyer la queue de la liste
#         '''
#         pass
#  ```

# %% [markdown]
# <div class="alert alert-warning">
# <img src="Images/CR.png" alt="logo CR" width=5% align=right>
#
# Travail à faire
#
# Définir une classe **Liste** implémentant l'interface **InterfaceListe**.
# <br>Le constructeur aura deux arguments :
# - L'argument **donnee** : type entier, avec pour valeur par défaut **None**
# - Le paramètre **liste** : type **Liste**, avec pour valeur par défaut **None**
#
# Il devra initialiser l'attribut d'instance **tete** qui représente le premier noeud de la liste.
# Trois cas sont possibles :
# - La liste est vide : l'attribut **tete** est initialisé à **None** ;
# - La liste comporte un seul noeud : l'attribut **tete** est initialisé avec le noeud **[{donnee} None]** ;
# - La liste comporte plus d'un noeud : l'attribut **tete** est initialisé avec le noeud : **[donnee, noeud de tete de la liste passée en argument]**
#
# La méthode spéciale `__repr__` qui renverra de manière récursive, la chaîne de caractères représentant le premier noeud ainsi que ses successeurs ou le message 'La liste est vide' si celle-ci l'est.
#
# *Exemple d'exécution* :
#
# l1=Liste()
#
# l2=Liste(2)
#
# l3=Liste(3,l2)
#
# print(l1)
#
# print(l2)
#
# print(l3)
#
# La liste est vide
#
# [2 None]
#
# [3 [2  None]]
#
#
# <div>

# %%
class Noeud:
    """
    classe implémentant un noeud (ou maillon).
    Le premier argument passé à l'instanciation est la donnée
    Le second set le lien vers le noeud suivant.
    """
    def __init__(self, donnee=None, noeud_suivant=None):
        self.donnee = donnee
        self.suivant = noeud_suivant

    def affiche_noeud(self): # faire un test avec la méthode __str__ pour voir la différence.
        """
        Méthode qui permet d'afficher
        le noeud passé en paramètre
        """
        return f'[{self.donnee}  . ]'

    def __repr__(self):
        """
        Méthode qui permet d'afficher
        de manière récursive la liste chainée
        à partir du noeud passé en paramètre
        """
        return f'[{self.donnee}  {self.suivant}]'


class Liste:
    """
    Classe implémentant une liste chaînée
    """
    def __init__(self, donnee=None, liste=None):
        '''
        Constructeur permettant de créer une nouvelle liste. Cette liste peut être :
            - Une liste vide
            - Une liste ayant pour tête le maillon contenant donnee et pour queue liste
                 argument donnee : Donnée à ajouter en tête de liste
                 argument liste : Liste représentant la queue de nouvelle liste
        '''
        if donnee is None:
            self.tete = None
        elif liste is None:
            self.tete = Noeud(donnee, None)
        else:
            self.tete = Noeud(donnee, liste.tete)
    
    def __repr__(self):
            if self.tete is None:
                return 'La liste est vide'
            else:
                return f'[{self.tete.donnee} {self.tete.suivant}]'

# %%
if __name__=='__main__':
    l1=Liste()
    l2=Liste(2)
    l3=Liste(3,l2)
    print(l1)
    print(l2)
    print(l3)

# %% [markdown]
# <div class="alert alert-warning">
# <img src="Images/CR.png" alt="logo CR" width=5% align=right>
#
# Travail à faire
#
# Compléter le corps des méthodes **est_vide**, **insere**, **supprime** et testez les.
# <div>

# %%
class Noeud:
    """
    classe implémentant un noeud (ou maillon).
    Le premier argument passé à l'instanciation est la donnée
    Le second set le lien vers le noeud suivant.
    """
    def __init__(self, donnee=None, noeud_suivant=None):
        self.donnee = donnee
        self.suivant = noeud_suivant

    def affiche_noeud(self): # faire un test avec la méthode __str__ pour voir la différence.
        """
        Méthode qui permet d'afficher
        le noeud passé en paramètre
        """
        return f'[{self.donnee}  . ]'

    def __repr__(self):
        """
        Méthode qui permet d'afficher
        de manière récursive la liste chainée
        à partir du noeud passé en paramètre
        """
        return f'[{self.donnee}  {self.suivant}]'


class Liste:
    """
    Classe implémentant une liste chaînée
    """
    def __init__(self, donnee=None, liste=None):
        '''
        Constructeur permettant de créer une nouvelle liste. Cette liste peut être :
            - Une liste vide
            - Une liste ayant pour tête le maillon contenant donnee et pour queue liste
                 argument donnee : Donnée à ajouter en tête de liste
                 argument liste : Liste représentant la queue de nouvelle liste
        '''
        if donnee is None:
            self.tete = None
        elif liste is None:
            self.tete = Noeud(donnee, None)
        else:
            self.tete = Noeud(donnee, liste.tete)
    
    def __repr__(self):
            if self.tete is None:
                return 'La liste est vide'
            else:
                return f'[{self.tete.donnee} {self.tete.suivant}]'

    
    def est_vide(self) -> bool:
        '''
        Méthode permettant de tester si la liste est vide
        renvoie True si la liste est vide, False sinon
        '''
        return self.tete==None

    def insere(self, donnee : int):
        '''
        Méthode permettant d'ajouter un noeud en tête de liste
        argument donnee : donnée du noeud à ajouter
        '''
        assert isinstance(donnee,int),'Opération impossible : donnée incompatible'
        self.tete=Noeud(donnee,self.tete)

    def supprime(self):
        '''
        Méthode permettant de supprimer le noeud en tête de liste
        '''
        assert not(self.est_vide()), 'La liste est vide'
        self.tete = self.tete.suivant

# %%
if __name__=='__main__':
    l1=Liste()
    l2=Liste(2)
    l3=Liste(3,l2)
    l4=Liste()
    l1.est_vide()
    l1.insere(7)
    l1.insere(12)
    print(l1)
    print(l3)
    l3.supprime()
    print(l3)

# %% [markdown]
# <div class="alert alert-warning">
# <img src="Images/CR.png" alt="logo CR" width=5% align=right>
#
# Travail à faire
#
# Compléter le corps des méthodes **get_tete**, **get_queue** et testez les.
# <div>

# %%
class Noeud:
    """
    classe implémentant un noeud (ou maillon).
    Le premier argument passé à l'instanciation est la donnée
    Le second set le lien vers le noeud suivant.
    """
    def __init__(self, donnee=None, noeud_suivant=None):
        self.donnee = donnee
        self.suivant = noeud_suivant

    def affiche_noeud(self): # faire un test avec la méthode __str__ pour voir la différence.
        """
        Méthode qui permet d'afficher
        le noeud passé en paramètre
        """
        return f'[{self.donnee}  . ]'

    def __repr__(self):
        """
        Méthode qui permet d'afficher
        de manière récursive la liste chainée
        à partir du noeud passé en paramètre
        """
        return f'[{self.donnee}  {self.suivant}]'


class Liste:
    """
    Classe implémentant une liste chaînée
    """
    def __init__(self, donnee=None, liste=None):
        '''
        Constructeur permettant de créer une nouvelle liste. Cette liste peut être :
            - Une liste vide
            - Une liste ayant pour tête le maillon contenant donnee et pour queue liste
                 argument donnee : Donnée à ajouter en tête de liste
                 argument liste : Liste représentant la queue de nouvelle liste
        '''
        if donnee is None:
            self.tete = None
        elif liste is None:
            self.tete = Noeud(donnee, None)
        else:
            self.tete = Noeud(donnee, liste.tete)
    
    def __repr__(self):
            if self.tete is None:
                return 'La liste est vide'
            else:
                return f'[{self.tete.donnee} {self.tete.suivant}]'

    
    def est_vide(self) -> bool:
        '''
        Méthode permettant de tester si la liste est vide
        renvoie True si la liste est vide, False sinon
        '''
        return self.tete==None

    def insere(self, donnee : int):
        '''
        Méthode permettant d'ajouter un noeud en tête de liste
        argument donnee : donnée du noeud à ajouter
        '''
        assert isinstance(donnee,int),'Opération impossible : donnée incompatible'
        self.tete=Noeud(donnee,self.tete)

    def supprime(self):
        '''
        Méthode permettant de supprimer le noeud en tête de liste
        '''
        assert not(self.est_vide()), 'La liste est vide'
        self.tete = self.tete.suivant
    
    def get_tete(self)-> int:
        '''
        Méthode permettant de renvoyer la donnée du noeud en tête
        de liste
        '''
        assert not(self.est_vide()), 'La liste est vide'
        return self.tete.donnee

    def get_queue(self)-> Liste:
        '''
        Méthode permettant de renvoyer la queue de la liste
        '''
        assert not(self.est_vide()), 'La liste est vide'
        liste = Liste()
        liste.tete = self.tete.suivant
        return liste
        
    """
    Non demandé
    """

    def longueur(self)-> int:
        '''
        Méthode permettant de renvoyer la longueur de la liste
        '''
        noeud = self.tete
        long = 0
        while noeud is not None:
            long+= 1
            noeud = noeud.suivant
        return long
    
    # utilisation d'un wrapper
    def long_recursif(self):
        return self.longueur1(self.tete)
 
    def longueur1(self, noeud):
        if noeud is None:
            return 0
        return 1 + self.longueur1(noeud.suivant)

# %%
if __name__=='__main__':
    l1=Liste()
    l1.insere(7)
    l1.insere(12)

# %%
class Noeud:
    """
    classe implémentant un noeud (ou maillon).
    Le premier argument passé à l'instanciation est la donnée
    Le second set le lien vers le noeud suivant.
    """
    def __init__(self, donnee=None, noeud_suivant=None):
        self.donnee = donnee
        self.suivant = noeud_suivant

    def affiche_noeud(self): # faire un test avec la méthode __str__ pour voir la différence.
        """
        Méthode qui permet d'afficher
        le noeud passé en paramètre
        """
        return f'[{self.donnee}  . ]'

    def __repr__(self):
        """
        Méthode qui permet d'afficher
        de manière récursive la liste chainée
        à partir du noeud passé en paramètre
        """
        return f'[{self.donnee}  {self.suivant}]'


class Liste:
    """
    Classe implémentant une liste chaînée
    """
    def __init__(self, donnee=None, liste=None):
        '''
        Constructeur permettant de créer une nouvelle liste. Cette liste peut être :
            - Une liste vide
            - Une liste ayant pour tête le maillon contenant donnee et pour queue liste
                 argument donnee : Donnée à ajouter en tête de liste
                 argument liste : Liste représentant la queue de nouvelle liste
        '''
        if donnee is None:
            self.tete = None
        elif liste is None:
            self.tete = Noeud(donnee, None)
        else:
            self.tete = Noeud(donnee, liste.tete)
    
    def __repr__(self):
            if self.tete is None:
                return 'La liste est vide'
            else:
                return f'[{self.tete.donnee} {self.tete.suivant}]'

    
    def est_vide(self) -> bool:
        '''
        Méthode permettant de tester si la liste est vide
        renvoie True si la liste est vide, False sinon
        '''
        return self.tete==None

    def insere(self, donnee : int):
        '''
        Méthode permettant d'ajouter un noeud en tête de liste
        argument donnee : donnée du noeud à ajouter
        '''
        assert isinstance(donnee,int),'Opération impossible : donnée incompatible'
        self.tete=Noeud(donnee,self.tete)

    def supprime(self):
        '''
        Méthode permettant de supprimer le noeud en tête de liste
        '''
        assert not(self.est_vide()), 'La liste est vide'
        self.tete = self.tete.suivant
    
    def get_tete(self)-> int:
        '''
        Méthode permettant de renvoyer la donnée du noeud en tête
        de liste
        '''
        assert not(self.est_vide()), 'La liste est vide'
        return self.tete.donnee

    def get_queue(self)-> Liste:
        '''
        Méthode permettant de renvoyer la queue de la liste
        '''
        assert not(self.est_vide()), 'La liste est vide'
        liste = Liste()
        liste.tete = self.tete.suivant
        return liste

# %%
if __name__=='__main__':
    l1=Liste()
    l1.insere(7)
    l1.insere(12)
    print(l1)
    l3=l1.get_queue()
    print(l3)
    data=l1.get_tete()
    print(data)
    l4=Liste(l1.get_tete(),l1.get_queue())
    print(l4)
# Out:
# [12 [7  None]]
# [7 None]
# 12
# [12 [7  None]]

# %%
type(l2)
# Out:
# int

# %% [markdown]
# ### 2- Implémentation  d'une pile

# %% [markdown]
# ### 3- Implémentation  d'une file
